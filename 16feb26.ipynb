# %% [markdown]
# <a href="https://colab.research.google.com/github/karthiknaik777111-eng/ATM-Simulation/blob/coding---practice/16feb26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Find Missing Number

# %%
lst = [1, 2, 4, 5]  # missing 3

n = 5
expected = n * (n + 1) // 2
actual = sum(lst)

print("Missing:", expected - actual)
# Out:
# Missing: 3
