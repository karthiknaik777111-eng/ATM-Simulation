# %% [markdown]
# <a href="https://colab.research.google.com/github/karthiknaik777111-eng/ATM-Simulation/blob/coding---practice/14feb26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Frequency of elements

# %%
lst = [1, 2, 2, 3, 3, 3]

freq = {}
for i in lst:
    if i in freq:
        freq[i] += 1
    else:
        freq[i] = 1

print(freq)
# Out:
# {1: 1, 2: 2, 3: 3}
